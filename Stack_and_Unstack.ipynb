# %%
import pandas as pd,numpy as np,matplotlib.pyplot as plt,seaborn as sns

# %%
datasets_list = sns.get_dataset_names()
datasets_list
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
planets=sns.load_dataset('planets')
planets
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
planets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %%
x = planets.groupby(['method'])[['mass','distance','orbital_period']].agg(['mean','median','std','min','max'])

# %%
x
# Out:
#                                    mass                                  \
#                                    mean median       std     min    max
# method
# Astrometry                          NaN    NaN       NaN     NaN    NaN
# Eclipse Timing Variations      5.125000  5.125  1.308148  4.2000   6.05
# Imaging                             NaN    NaN       NaN     NaN    NaN
# Microlensing                        NaN    NaN       NaN     NaN    NaN
# Orbital Brightness Modulation       NaN    NaN       NaN     NaN    NaN
# Pulsar Timing                       NaN    NaN       NaN     NaN    NaN
# Pulsation Timing Variations         NaN    NaN       NaN     NaN    NaN
# Radial Velocity                2.630699  1.260  3.825883  0.0036  25.00
# Transit                        1.470000  1.470       NaN  1.4700   1.47
# Transit Timing Variations           NaN    NaN       NaN     NaN    NaN
#
#                                   distance                                  \
# ...

# %% [markdown]
# ### STACK() : The stack method is used to pivot a level of the column labels (DataFrame's columns) to the innermost level of a MultiIndex on the rows (DataFrame's index). It "stacks" the specified level(s) from the columns to the rows.
#
# ##### SYNTAX :  DataFrame.stack(level=-1, dropna=True)
# ##### LEVEL : It tells level or levels to be stacked

# %%
planets_stack = x.stack(level=0) # stack(level=0)- to stack the level with index 0 of the columns. 
planets_stack
# Out:
#                                                         max           mean  \
# method
# Astrometry                    distance            20.770000      17.875000
#                               orbital_period    1016.000000     631.180000
# Eclipse Timing Variations     distance           500.000000     315.360000
#                               mass                 6.050000       5.125000
#                               orbital_period   10220.000000    4751.644444
# Imaging                       distance           165.000000      67.715937
#                               orbital_period  730000.000000  118247.737500
# Microlensing                  distance          7720.000000    4144.000000
#                               orbital_period    5100.000000    3153.571429
# Orbital Brightness Modulation distance          1180.000000    1180.000000
#                               orbital_period       1.544929       0.709307
# ...

# %%
x.stack(level=1) # stack(level=1)- to stack the level with index 1 of the columns.
# Out:
#                                            mass     distance  orbital_period
# method
# Astrometry                    mean          NaN    17.875000      631.180000
#                               median        NaN    17.875000      631.180000
#                               std           NaN     4.094148      544.217663
#                               min           NaN    14.980000      246.360000
#                               max           NaN    20.770000     1016.000000
# Eclipse Timing Variations     mean     5.125000   315.360000     4751.644444
#                               median   5.125000   315.360000     4343.500000
#                               std      1.308148   213.203907     2499.130945
#                               min      4.200000   130.720000     1916.250000
#                               max      6.050000   500.000000    10220.000000
# Imaging                       mean          NaN    67.715937   118247.737500
# ...

# %% [markdown]
# ##### Unstack() :The unstack function is used to pivot or reshape a DataFrame by moving a level of the index to become a level of the columns. This operation is the reverse of the stack function.
# ##### unstack is particularly useful when you have a DataFrame with a MultiIndex on its rows, and you want to move one of these levels back to the columns.
#
# ##### SYNTAX : DataFrame.unstack(level=-1, fill_value=None)

# %%
planets_stack.unstack(level=0)
# Out:
#                       max                                                   \
# method         Astrometry Eclipse Timing Variations   Imaging Microlensing
# distance            20.77                    500.00     165.0       7720.0
# mass                  NaN                      6.05       NaN          NaN
# orbital_period    1016.00                  10220.00  730000.0       5100.0
#
#                                                             \
# method         Orbital Brightness Modulation Pulsar Timing
# distance                         1180.000000        1200.0
# mass                                     NaN           NaN
# orbital_period                      1.544929       36525.0
#
#                                                                         \
# method         Pulsation Timing Variations Radial Velocity     Transit
# distance                               NaN           354.0  8500.00000
# mass                                   NaN            25.0     1.47000
# ...

# %%
planets_stack.unstack(level=1)
# Out:
#                                    max                               mean  \
#                               distance   mass orbital_period     distance
# method
# Astrometry                       20.77    NaN    1016.000000    17.875000
# Eclipse Timing Variations       500.00   6.05   10220.000000   315.360000
# Imaging                         165.00    NaN  730000.000000    67.715937
# Microlensing                   7720.00    NaN    5100.000000  4144.000000
# Orbital Brightness Modulation  1180.00    NaN       1.544929  1180.000000
# Pulsar Timing                  1200.00    NaN   36525.000000  1200.000000
# Pulsation Timing Variations        NaN    NaN    1170.000000          NaN
# Radial Velocity                 354.00  25.00   17337.500000    51.600208
# Transit                        8500.00   1.47     331.600590   599.298080
# Transit Timing Variations      2119.00    NaN     160.000000  1104.333333
#
# ...
